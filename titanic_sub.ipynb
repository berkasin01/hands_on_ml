# %%
import pandas as pd 

train_df = pd.read_csv("datasets/titanic/train.csv")
test_df = pd.read_csv("datasets/titanic/test.csv")

# %%
print(train_df.shape)
train_df.head(10)
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(test_df.shape)
test_df.head(10)
# Out:
# (418, 11)
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
train_df["Cabin"].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F33            3
# E101           3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

train_df_prep = train_df.copy()
le= LabelEncoder()
train_df_prep["Sex"] = le.fit_transform(train_df_prep["Sex"])

le_2 = LabelEncoder()
train_df_prep["Embarked"] = le_2.fit_transform(train_df_prep["Embarked"])

train_df_prep = train_df_prep.drop(["PassengerId"],axis=1)
train_df_prep = train_df_prep.drop(["Name"],axis=1)

# %%
train_df_prep.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    1  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1       1    0  38.0      1      0          PC 17599  71.2833   C85
# 2         1       3    0  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    0  35.0      1      0            113803  53.1000  C123
# 4         0       3    1  35.0      0      0            373450   8.0500   NaN
#
#    Embarked
# 0         2
# 1         0
# 2         2
# 3         2
# 4         2

# %%
le3 = LabelEncoder()
train_df_prep["Ticket"] = le3.fit_transform(train_df_prep["Ticket"])

le4 = LabelEncoder()
train_df_prep["Cabin"] = le4.fit_transform(train_df_prep["Cabin"])

# %%
features = train_df_prep.columns.tolist()
features.remove("Cabin")
features
# Out:
# ['Survived',
#  'Pclass',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Embarked']

# %%
cabin_train_df = train_df_prep[train_df_prep["Cabin"] != 147]
cabin_test_df = train_df_prep[train_df_prep["Cabin"] == 147]

# %%
cabin_train_df.shape
# Out:
# (204, 10)

# %%
cabin_test_df.shape
# Out:
# (687, 10)

# %%
X_train = cabin_train_df[features]
y_train = cabin_train_df["Cabin"].values

X_test = cabin_test_df[features]
y_test = cabin_test_df["Cabin"].values

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")
X_train[["Age","Fare"]] = imputer.fit_transform(X_train[["Age","Fare"]])
X_test[["Age","Fare"]] = imputer.transform(X_test[["Age","Fare"]])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train[["Age","Fare"]] = scaler.fit_transform(X_train[["Age","Fare"]])
X_test[["Age","Fare"]] = scaler.transform(X_test[["Age","Fare"]])

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

# %%
y_hat = rfc.predict(X_test)

# %%
cabin_test_df.loc[cabin_test_df["Cabin"] == 147, "Cabin"] = y_hat

# %%
prep_df = pd.concat([cabin_train_df, cabin_test_df]).sort_index()

# %%
prep_df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0           0       3    1  22.0      1      0     523   7.2500    140
# 1           1       1    0  38.0      1      0     596  71.2833     81
# 2           1       3    0  26.0      0      0     669   7.9250    115
# 3           1       1    0  35.0      1      0      49  53.1000     55
# 4           0       3    1  35.0      0      0     472   8.0500    143
# ..        ...     ...  ...   ...    ...    ...     ...      ...    ...
# 886         0       2    1  27.0      0      0     101  13.0000    111
# 887         1       1    0  19.0      0      0      14  30.0000     30
# 888         0       3    0   NaN      1      2     675  23.4500    145
# 889         1       1    1  26.0      0      0       8  30.0000     60
# 890         0       3    1  32.0      0      0     466   7.7500    143
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# 4           2
# ..        ...
# ...

# %%
prep_df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin         0
# Embarked      0
# dtype: int64

# %%
imputer = SimpleImputer(strategy="mean")
prep_df["Age"] = imputer.fit_transform(prep_df[["Age"]])

scaler = StandardScaler()
prep_df[["Age","Fare"]] = scaler.fit_transform(prep_df[["Age","Fare"]])

# %%
features = prep_df.columns.tolist()
features.remove("Survived")
features
# Out:
# ['Pclass',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
X = prep_df[features]
y = prep_df["Survived"]

# %%
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test_df["Sex"] = le.transform(test_df["Sex"])
test_df["Embarked"] = le_2.transform(test_df["Embarked"])
test_df["Ticket"] = le3.transform(test_df["Ticket"])
test_df["Cabin"] = le4.transform(test_df["Cabin"])

test_df["Age"] = imputer.transform(test_df[["Age"]])
test_df[["Age","Fare"]] = scaler.transform(test_df[["Age","Fare"]])

test_df = test_df.drop(["PassengerId"],axis=1)
test_df = test_df.drop(["Name"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\utils\_encode.py:229, in _encode(values, uniques, check_unknown)
#     228 try:
# --> 229     return _map_to_integer(values, uniques)
#     230 except KeyError as e:
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\utils\_encode.py:168, in _map_to_integer(values, uniques)
#     167 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 168 return xp.asarray([table[v] for v in values], device=device(values))
#
# File ~\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\sklearn\utils\_encode.py:161, in _nandict.__missing__(self, key)
#     160     return self.nan_value
# --> 161 raise KeyError(key)
#
# KeyError: '330911'
#
# During handling of the above exception, another exception occurred:
#
# ...
