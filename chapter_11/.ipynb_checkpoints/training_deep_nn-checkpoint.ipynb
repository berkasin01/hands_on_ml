# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
##keras.layers.Dense(10,activation="relu",kernel_initializer="he_normal")

# %%
##keras.layers.Dense(10,kernel_initiliazer="he_normal")
##keras.layers.LeakyReLU(alpha=0.2)
