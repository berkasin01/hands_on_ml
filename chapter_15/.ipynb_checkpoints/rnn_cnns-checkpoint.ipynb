# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0,1,n_steps)

    series = 0.5 * np.sin(( time - offsets1) * (freq1 * 10 + 10)) #wave 1
    series += 0.5 * np.sin(( time - offsets2) * (freq2 * 20 + 20)) #2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) #noise
    return series[..., np.newaxis].astype(np.float32)

# %%
n_steps = 50
series = generate_time_series(10000,n_steps+1)

# %%
new_n_steps = 1
new_series = generate_time_series(10,new_n_steps+1)

# %%
new_series
# Out:
# array([[[-0.2604454 ],
#         [-0.04947499]],
#
#        [[ 0.36620814],
#         [ 0.35534525]],
#
#        [[-0.83663636],
#         [-0.05664493]],
#
#        [[ 0.06891673],
#         [-0.05376686]],
#
#        [[ 0.2939557 ],
#         [-0.45254594]],
#
#        [[-0.01000415],
#         [ 0.16417463]],
#
#        [[ 0.37858993],
#         [-0.28237262]],
#
#        [[-0.16340347],
#         [-0.8372189 ]],
#
#        [[ 0.63184166],
#         [-0.38512912]],
#
#        [[ 0.16136944],
#         [-0.20445995]]], dtype=float32)

# %%
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_valid, y_valid = series[9000:, :n_steps], series[9000:, -1]

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.MeanSquaredError()(y_valid, y_pred))
# Out:
# np.float32(0.060569648)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50,1]),
    keras.layers.Dense(1)])
model.compile(loss="mse",optimizer="sgd",metrics=["mae"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train,y_train,epochs=30,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1607 - mae: 0.3031 - val_loss: 0.0590 - val_mae: 0.1988
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0385 - mae: 0.1593 - val_loss: 0.0307 - val_mae: 0.1413
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0245 - mae: 0.1262 - val_loss: 0.0232 - val_mae: 0.1206
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0194 - mae: 0.1116 - val_loss: 0.0194 - val_mae: 0.1089
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0164 - mae: 0.1023 - val_loss: 0.0166 - val_mae: 0.1008
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - mae: 0.0953 - val_loss: 0.0146 - val_mae: 0.0948
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0125 - mae: 0.0897 - val_loss: 0.0130 - val_mae: 0.0895
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0113 - mae: 0.0855 - val_loss: 0.0118 - val_mae: 0.0853
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0103 - mae: 0.0817 - val_loss: 0.0109 - val_mae: 0.0820
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.0096 - mae: 0.0788 - val_loss: 0.0101 - val_mae: 0.0794
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 0.0090 - mae: 0.0764 - val_loss: 0.0096 - val_mae: 0.0776
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0086 - mae: 0.0744 - val_loss: 0.0091 - val_mae: 0.0756
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0082 - mae: 0.0727 - val_loss: 0.0086 - val_mae: 0.0740
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0079 - mae: 0.0715 - val_loss: 0.0084 - val_mae: 0.0730
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0077 - mae: 0.0703 - val_loss: 0.0082 - val_mae: 0.0718
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0075 - mae: 0.0694 - val_loss: 0.0079 - val_mae: 0.0709
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0073 - mae: 0.0685 - val_loss: 0.0077 - val_mae: 0.0700
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0072 - mae: 0.0679 - val_loss: 0.0076 - val_mae: 0.0692
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0071 - mae: 0.0671 - val_loss: 0.0074 - val_mae: 0.0687
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.0069 - mae: 0.0667 - val_loss: 0.0073 - val_mae: 0.0680
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0068 - mae: 0.0661 - val_loss: 0.0072 - val_mae: 0.0676
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0067 - mae: 0.0657 - val_loss: 0.0070 - val_mae: 0.0669
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0067 - mae: 0.0652 - val_loss: 0.0069 - val_mae: 0.0665
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0066 - mae: 0.0648 - val_loss: 0.0069 - val_mae: 0.0662
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.0065 - mae: 0.0644 - val_loss: 0.0068 - val_mae: 0.0656
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0064 - mae: 0.0641 - val_loss: 0.0067 - val_mae: 0.0651
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0064 - mae: 0.0637 - val_loss: 0.0066 - val_mae: 0.0650
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0063 - mae: 0.0634 - val_loss: 0.0066 - val_mae: 0.0646
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0062 - mae: 0.0631 - val_loss: 0.0065 - val_mae: 0.0642
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0062 - mae: 0.0628 - val_loss: 0.0064 - val_mae: 0.0642

# %%
rnnmodel = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None,1])
])
# Out:
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
rnnmodel.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rnnmodel.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnnmodel.fit(X_train,y_train,epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0838 - mae: 0.2334 - val_loss: 0.0670 - val_mae: 0.2104
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0545 - mae: 0.1886 - val_loss: 0.0471 - val_mae: 0.1769
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0406 - mae: 0.1646 - val_loss: 0.0381 - val_mae: 0.1608
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0344 - mae: 0.1534 - val_loss: 0.0343 - val_mae: 0.1547
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0317 - mae: 0.1484 - val_loss: 0.0326 - val_mae: 0.1520
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0303 - mae: 0.1460 - val_loss: 0.0317 - val_mae: 0.1505
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0295 - mae: 0.1445 - val_loss: 0.0311 - val_mae: 0.1495
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0290 - mae: 0.1432 - val_loss: 0.0307 - val_mae: 0.1486
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0285 - mae: 0.1423 - val_loss: 0.0303 - val_mae: 0.1479
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0282 - mae: 0.1414 - val_loss: 0.0300 - val_mae: 0.1472
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0279 - mae: 0.1406 - val_loss: 0.0297 - val_mae: 0.1465
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0276 - mae: 0.1400 - val_loss: 0.0295 - val_mae: 0.1459
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0274 - mae: 0.1394 - val_loss: 0.0293 - val_mae: 0.1454
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0272 - mae: 0.1388 - val_loss: 0.0291 - val_mae: 0.1450
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0270 - mae: 0.1384 - val_loss: 0.0290 - val_mae: 0.1446
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0268 - mae: 0.1380 - val_loss: 0.0288 - val_mae: 0.1443
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0267 - mae: 0.1376 - val_loss: 0.0287 - val_mae: 0.1440
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0266 - mae: 0.1373 - val_loss: 0.0286 - val_mae: 0.1438
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0265 - mae: 0.1371 - val_loss: 0.0286 - val_mae: 0.1436
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0264 - mae: 0.1369 - val_loss: 0.0285 - val_mae: 0.1434
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0263 - mae: 0.1367 - val_loss: 0.0285 - val_mae: 0.1433
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0263 - mae: 0.1365 - val_loss: 0.0284 - val_mae: 0.1431
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0262 - mae: 0.1364 - val_loss: 0.0284 - val_mae: 0.1430
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0262 - mae: 0.1363 - val_loss: 0.0283 - val_mae: 0.1429
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0261 - mae: 0.1362 - val_loss: 0.0283 - val_mae: 0.1429
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0261 - mae: 0.1361 - val_loss: 0.0283 - val_mae: 0.1428
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0261 - mae: 0.1360 - val_loss: 0.0283 - val_mae: 0.1427
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0261 - mae: 0.1359 - val_loss: 0.0283 - val_mae: 0.1427
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0261 - mae: 0.1359 - val_loss: 0.0283 - val_mae: 0.1427
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0260 - mae: 0.1359 - val_loss: 0.0283 - val_mae: 0.1426

# %%
rnn_fully_model = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
        keras.layers.SimpleRNN(20, return_sequences=True),
        keras.layers.SimpleRNN(1)
])

# %%
rnn_fully_model.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnn_fully_model.fit(X_train,y_train, epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1078 - mae: 0.2512 - val_loss: 0.0444 - val_mae: 0.1678
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0300 - mae: 0.1376 - val_loss: 0.0254 - val_mae: 0.1285
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0194 - mae: 0.1116 - val_loss: 0.0182 - val_mae: 0.1098
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0152 - mae: 0.0989 - val_loss: 0.0148 - val_mae: 0.0991
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0129 - mae: 0.0912 - val_loss: 0.0135 - val_mae: 0.0947
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0115 - mae: 0.0862 - val_loss: 0.0120 - val_mae: 0.0892
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0104 - mae: 0.0822 - val_loss: 0.0109 - val_mae: 0.0849
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0097 - mae: 0.0799 - val_loss: 0.0103 - val_mae: 0.0826
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0091 - mae: 0.0772 - val_loss: 0.0096 - val_mae: 0.0798
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0086 - mae: 0.0751 - val_loss: 0.0094 - val_mae: 0.0781
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0083 - mae: 0.0736 - val_loss: 0.0088 - val_mae: 0.0759
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0079 - mae: 0.0721 - val_loss: 0.0086 - val_mae: 0.0749
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0077 - mae: 0.0707 - val_loss: 0.0083 - val_mae: 0.0731
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0075 - mae: 0.0698 - val_loss: 0.0080 - val_mae: 0.0717
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0073 - mae: 0.0688 - val_loss: 0.0077 - val_mae: 0.0703
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0071 - mae: 0.0678 - val_loss: 0.0078 - val_mae: 0.0708
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0069 - mae: 0.0672 - val_loss: 0.0075 - val_mae: 0.0694
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0068 - mae: 0.0666 - val_loss: 0.0072 - val_mae: 0.0681
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0067 - mae: 0.0661 - val_loss: 0.0072 - val_mae: 0.0679
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0066 - mae: 0.0654 - val_loss: 0.0070 - val_mae: 0.0666
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0065 - mae: 0.0650 - val_loss: 0.0074 - val_mae: 0.0696
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0064 - mae: 0.0645 - val_loss: 0.0068 - val_mae: 0.0656
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0063 - mae: 0.0641 - val_loss: 0.0067 - val_mae: 0.0652
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0063 - mae: 0.0638 - val_loss: 0.0068 - val_mae: 0.0659
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - mae: 0.0635 - val_loss: 0.0068 - val_mae: 0.0664
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0062 - mae: 0.0632 - val_loss: 0.0065 - val_mae: 0.0641
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0061 - mae: 0.0630 - val_loss: 0.0064 - val_mae: 0.0638
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0061 - mae: 0.0627 - val_loss: 0.0064 - val_mae: 0.0636
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0060 - mae: 0.0625 - val_loss: 0.0063 - val_mae: 0.0632
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0060 - mae: 0.0623 - val_loss: 0.0063 - val_mae: 0.0632

# %%
rnn_fully_model_dense = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
        keras.layers.SimpleRNN(20),
        keras.layers.Dense(1)
])

# %%
rnn_fully_model_dense.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnn_fully_model_dense.fit(X_train,y_train, epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0427 - mae: 0.1533 - val_loss: 0.0197 - val_mae: 0.1112
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0156 - mae: 0.0983 - val_loss: 0.0139 - val_mae: 0.0943
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0116 - mae: 0.0856 - val_loss: 0.0110 - val_mae: 0.0836
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - mae: 0.0779 - val_loss: 0.0095 - val_mae: 0.0780
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0084 - mae: 0.0730 - val_loss: 0.0083 - val_mae: 0.0729
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0076 - mae: 0.0697 - val_loss: 0.0078 - val_mae: 0.0712
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - mae: 0.0666 - val_loss: 0.0071 - val_mae: 0.0680
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - mae: 0.0648 - val_loss: 0.0072 - val_mae: 0.0675
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - mae: 0.0630 - val_loss: 0.0064 - val_mae: 0.0640
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - mae: 0.0618 - val_loss: 0.0064 - val_mae: 0.0640
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0057 - mae: 0.0605 - val_loss: 0.0059 - val_mae: 0.0613
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - mae: 0.0596 - val_loss: 0.0058 - val_mae: 0.0611
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - mae: 0.0588 - val_loss: 0.0056 - val_mae: 0.0605
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - mae: 0.0581 - val_loss: 0.0055 - val_mae: 0.0594
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0052 - mae: 0.0577 - val_loss: 0.0053 - val_mae: 0.0585
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - mae: 0.0569 - val_loss: 0.0054 - val_mae: 0.0596
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - mae: 0.0565 - val_loss: 0.0051 - val_mae: 0.0577
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - mae: 0.0560 - val_loss: 0.0050 - val_mae: 0.0570
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - mae: 0.0559 - val_loss: 0.0052 - val_mae: 0.0580
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - mae: 0.0552 - val_loss: 0.0050 - val_mae: 0.0567
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - mae: 0.0551 - val_loss: 0.0048 - val_mae: 0.0558
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - mae: 0.0549 - val_loss: 0.0050 - val_mae: 0.0566
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - mae: 0.0544 - val_loss: 0.0049 - val_mae: 0.0568
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - mae: 0.0542 - val_loss: 0.0049 - val_mae: 0.0568
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - mae: 0.0541 - val_loss: 0.0047 - val_mae: 0.0555
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - mae: 0.0539 - val_loss: 0.0047 - val_mae: 0.0553
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0045 - mae: 0.0537 - val_loss: 0.0045 - val_mae: 0.0545
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - mae: 0.0534 - val_loss: 0.0046 - val_mae: 0.0546
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0044 - mae: 0.0530 - val_loss: 0.0045 - val_mae: 0.0547
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0043 - mae: 0.0527 - val_loss: 0.0047 - val_mae: 0.0552

# %%
series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = rnn_fully_model_dense.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X,y_pred_one],axis=1)

Y_pred = X[:, n_steps:]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
Y_pred
# Out:
# array([[[-0.76740164],
#         [-0.85665274],
#         [-0.69634396],
#         [-0.3715331 ],
#         [-0.03632146],
#         [ 0.23555747],
#         [ 0.30683246],
#         [ 0.20603342],
#         [-0.00769118],
#         [-0.24050874]]], dtype=float32)

# %%
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
model2 = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

# %%
model2.compile(loss="mse", optimizer="adam")
model2.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1304 - val_loss: 0.0672
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0561 - val_loss: 0.0464
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0419 - val_loss: 0.0388
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0337 - val_loss: 0.0314
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0301 - val_loss: 0.0266
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0258 - val_loss: 0.0238
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0239 - val_loss: 0.0273
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0204 - val_loss: 0.0192
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0174 - val_loss: 0.0187
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0162 - val_loss: 0.0147
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0144 - val_loss: 0.0133
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0126 - val_loss: 0.0117
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0123 - val_loss: 0.0152
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0111 - val_loss: 0.0122
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0111 - val_loss: 0.0099
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0103 - val_loss: 0.0096
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0097 - val_loss: 0.0089
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0098 - val_loss: 0.0085
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0082

# %%
series_new = generate_time_series(1, n_steps + 10)
X_new, Y_new = series_new[:, :n_steps], series_new[:, n_steps:, 0]
Y_pred = model2.predict(X_new)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step

# %%
Y_naive = np.tile(X_valid[:, -1], 10)
print(np.mean((Y_valid - Y_naive) ** 2))
print(model2.evaluate(X_valid, Y_valid))
# Out:
# 0.49721915
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082
# 0.008238651789724827
