# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0,1,n_steps)

    series = 0.5 * np.sin(( time - offsets1) * (freq1 * 10 + 10)) #wave 1
    series += 0.5 * np.sin(( time - offsets2) * (freq2 * 20 + 20)) #2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5) #noise
    return series[..., np.newaxis].astype(np.float32)

# %%
n_steps = 50
series = generate_time_series(10000,n_steps+1)

# %%
new_n_steps = 1
new_series = generate_time_series(10,new_n_steps+1)

# %%
new_series
# Out:
# array([[[ 0.35974616],
#         [-0.54191613]],
#
#        [[-0.08133569],
#         [-0.12376945]],
#
#        [[ 0.62980056],
#         [-0.1490191 ]],
#
#        [[-0.01977597],
#         [-0.00918195]],
#
#        [[ 0.5158635 ],
#         [ 0.42392033]],
#
#        [[ 0.2341435 ],
#         [-0.7478467 ]],
#
#        [[-0.295979  ],
#         [ 0.8069518 ]],
#
#        [[-0.5388288 ],
#         [-0.18826964]],
#
#        [[ 0.66146916],
#         [-0.09796509]],
#
#        [[-0.05722408],
#         [ 0.2610839 ]]], dtype=float32)

# %%
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_valid, y_valid = series[9000:, :n_steps], series[9000:, -1]

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.MeanSquaredError()(y_valid, y_pred))
# Out:
# np.float32(0.05942023)

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50,1]),
    keras.layers.Dense(1)])
model.compile(loss="mse",optimizer="sgd",metrics=["mae"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train,y_train,epochs=30,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1277 - mae: 0.2682 - val_loss: 0.0400 - val_mae: 0.1598
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0298 - mae: 0.1404 - val_loss: 0.0239 - val_mae: 0.1240
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0207 - mae: 0.1171 - val_loss: 0.0193 - val_mae: 0.1114
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172 - mae: 0.1059 - val_loss: 0.0167 - val_mae: 0.1042
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0149 - mae: 0.0984 - val_loss: 0.0145 - val_mae: 0.0974
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0131 - mae: 0.0923 - val_loss: 0.0130 - val_mae: 0.0923
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - mae: 0.0876 - val_loss: 0.0117 - val_mae: 0.0877
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - mae: 0.0837 - val_loss: 0.0108 - val_mae: 0.0844
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0100 - mae: 0.0805 - val_loss: 0.0099 - val_mae: 0.0810
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - mae: 0.0780 - val_loss: 0.0092 - val_mae: 0.0780
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089 - mae: 0.0758 - val_loss: 0.0088 - val_mae: 0.0761
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085 - mae: 0.0740 - val_loss: 0.0084 - val_mae: 0.0745
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - mae: 0.0725 - val_loss: 0.0081 - val_mae: 0.0727
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - mae: 0.0712 - val_loss: 0.0079 - val_mae: 0.0717
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0077 - mae: 0.0702 - val_loss: 0.0076 - val_mae: 0.0704
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0075 - mae: 0.0693 - val_loss: 0.0074 - val_mae: 0.0694
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 0.0073 - mae: 0.0684 - val_loss: 0.0073 - val_mae: 0.0687
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0072 - mae: 0.0678 - val_loss: 0.0072 - val_mae: 0.0683
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 0.0071 - mae: 0.0672 - val_loss: 0.0070 - val_mae: 0.0676
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0070 - mae: 0.0666 - val_loss: 0.0069 - val_mae: 0.0669
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.0069 - mae: 0.0662 - val_loss: 0.0069 - val_mae: 0.0667
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.0068 - mae: 0.0657 - val_loss: 0.0067 - val_mae: 0.0663
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.0067 - mae: 0.0653 - val_loss: 0.0067 - val_mae: 0.0658
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 0.0066 - mae: 0.0649 - val_loss: 0.0066 - val_mae: 0.0653
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - mae: 0.0646 - val_loss: 0.0065 - val_mae: 0.0648
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.0065 - mae: 0.0643 - val_loss: 0.0065 - val_mae: 0.0647
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 0.0064 - mae: 0.0640 - val_loss: 0.0064 - val_mae: 0.0644
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.0064 - mae: 0.0637 - val_loss: 0.0063 - val_mae: 0.0639
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0063 - mae: 0.0634 - val_loss: 0.0063 - val_mae: 0.0637
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0063 - mae: 0.0631 - val_loss: 0.0062 - val_mae: 0.0632

# %%
rnnmodel = keras.models.Sequential([
    keras.layers.SimpleRNN(1, input_shape=[None,1])
])
# Out:
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
rnnmodel.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rnnmodel.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnnmodel.fit(X_train,y_train,epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1938 - mae: 0.3560 - val_loss: 0.0933 - val_mae: 0.2545
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0684 - mae: 0.2185 - val_loss: 0.0558 - val_mae: 0.2001
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0513 - mae: 0.1911 - val_loss: 0.0483 - val_mae: 0.1860
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0462 - mae: 0.1812 - val_loss: 0.0446 - val_mae: 0.1784
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0432 - mae: 0.1750 - val_loss: 0.0419 - val_mae: 0.1728
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0408 - mae: 0.1700 - val_loss: 0.0398 - val_mae: 0.1682
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0388 - mae: 0.1659 - val_loss: 0.0379 - val_mae: 0.1644
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0372 - mae: 0.1623 - val_loss: 0.0364 - val_mae: 0.1610
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0357 - mae: 0.1592 - val_loss: 0.0351 - val_mae: 0.1580
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0345 - mae: 0.1564 - val_loss: 0.0339 - val_mae: 0.1554
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0335 - mae: 0.1540 - val_loss: 0.0329 - val_mae: 0.1531
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0325 - mae: 0.1518 - val_loss: 0.0320 - val_mae: 0.1511
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0317 - mae: 0.1499 - val_loss: 0.0313 - val_mae: 0.1493
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0310 - mae: 0.1482 - val_loss: 0.0306 - val_mae: 0.1477
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0304 - mae: 0.1467 - val_loss: 0.0300 - val_mae: 0.1463
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0299 - mae: 0.1453 - val_loss: 0.0295 - val_mae: 0.1451
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0294 - mae: 0.1441 - val_loss: 0.0290 - val_mae: 0.1440
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0290 - mae: 0.1430 - val_loss: 0.0286 - val_mae: 0.1430
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0286 - mae: 0.1421 - val_loss: 0.0283 - val_mae: 0.1421
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0283 - mae: 0.1413 - val_loss: 0.0280 - val_mae: 0.1414
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0280 - mae: 0.1405 - val_loss: 0.0277 - val_mae: 0.1408
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0278 - mae: 0.1399 - val_loss: 0.0275 - val_mae: 0.1402
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0275 - mae: 0.1394 - val_loss: 0.0273 - val_mae: 0.1397
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0274 - mae: 0.1389 - val_loss: 0.0271 - val_mae: 0.1393
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0272 - mae: 0.1385 - val_loss: 0.0269 - val_mae: 0.1389
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0271 - mae: 0.1382 - val_loss: 0.0268 - val_mae: 0.1386
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0270 - mae: 0.1379 - val_loss: 0.0267 - val_mae: 0.1383
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0269 - mae: 0.1377 - val_loss: 0.0266 - val_mae: 0.1381
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0268 - mae: 0.1375 - val_loss: 0.0266 - val_mae: 0.1379
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0267 - mae: 0.1373 - val_loss: 0.0265 - val_mae: 0.1377

# %%
rnn_fully_model = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
        keras.layers.SimpleRNN(20, return_sequences=True),
        keras.layers.SimpleRNN(1)
])

# %%
rnn_fully_model.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnn_fully_model.fit(X_train,y_train, epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.1067 - mae: 0.2278 - val_loss: 0.0259 - val_mae: 0.1287
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0220 - mae: 0.1186 - val_loss: 0.0172 - val_mae: 0.1054
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0171 - mae: 0.1047 - val_loss: 0.0185 - val_mae: 0.1098
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0149 - mae: 0.0980 - val_loss: 0.0136 - val_mae: 0.0936
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0134 - mae: 0.0927 - val_loss: 0.0128 - val_mae: 0.0910
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0112 - val_mae: 0.0851
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0116 - mae: 0.0865 - val_loss: 0.0108 - val_mae: 0.0837
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0109 - mae: 0.0838 - val_loss: 0.0101 - val_mae: 0.0808
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0105 - mae: 0.0823 - val_loss: 0.0106 - val_mae: 0.0833
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0101 - mae: 0.0806 - val_loss: 0.0097 - val_mae: 0.0792
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0097 - mae: 0.0791 - val_loss: 0.0093 - val_mae: 0.0778
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0095 - mae: 0.0781 - val_loss: 0.0090 - val_mae: 0.0764
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0092 - mae: 0.0766 - val_loss: 0.0085 - val_mae: 0.0745
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0090 - mae: 0.0758 - val_loss: 0.0088 - val_mae: 0.0759
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0088 - mae: 0.0751 - val_loss: 0.0084 - val_mae: 0.0742
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0086 - mae: 0.0743 - val_loss: 0.0082 - val_mae: 0.0723
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0084 - mae: 0.0737 - val_loss: 0.0081 - val_mae: 0.0726
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0082 - mae: 0.0728 - val_loss: 0.0079 - val_mae: 0.0714
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0081 - mae: 0.0723 - val_loss: 0.0077 - val_mae: 0.0704
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0080 - mae: 0.0717 - val_loss: 0.0081 - val_mae: 0.0726
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0079 - mae: 0.0714 - val_loss: 0.0079 - val_mae: 0.0716
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0078 - mae: 0.0706 - val_loss: 0.0075 - val_mae: 0.0692
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0077 - mae: 0.0704 - val_loss: 0.0075 - val_mae: 0.0691
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0076 - mae: 0.0700 - val_loss: 0.0075 - val_mae: 0.0692
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0075 - mae: 0.0695 - val_loss: 0.0074 - val_mae: 0.0686
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0075 - mae: 0.0691 - val_loss: 0.0072 - val_mae: 0.0678
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0074 - mae: 0.0691 - val_loss: 0.0072 - val_mae: 0.0673
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0074 - mae: 0.0688 - val_loss: 0.0072 - val_mae: 0.0674
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0073 - mae: 0.0683 - val_loss: 0.0072 - val_mae: 0.0675
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0072 - mae: 0.0679 - val_loss: 0.0070 - val_mae: 0.0666

# %%
rnn_fully_model_dense = keras.models.Sequential([
        keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
        keras.layers.SimpleRNN(20),
        keras.layers.Dense(1)
])

# %%
rnn_fully_model_dense.compile(loss="mse",optimizer="sgd",metrics=["mae"])

# %%
history = rnn_fully_model_dense.fit(X_train,y_train, epochs=30, validation_data=[X_valid,y_valid])
# Out:
# Epoch 1/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0475 - mae: 0.1634 - val_loss: 0.0210 - val_mae: 0.1152
# Epoch 2/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0161 - mae: 0.1007 - val_loss: 0.0149 - val_mae: 0.0982
# Epoch 3/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0119 - mae: 0.0867 - val_loss: 0.0108 - val_mae: 0.0824
# Epoch 4/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0097 - mae: 0.0783 - val_loss: 0.0096 - val_mae: 0.0779
# Epoch 5/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0085 - mae: 0.0734 - val_loss: 0.0084 - val_mae: 0.0728
# Epoch 6/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0076 - mae: 0.0694 - val_loss: 0.0075 - val_mae: 0.0689
# Epoch 7/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0070 - mae: 0.0665 - val_loss: 0.0070 - val_mae: 0.0666
# Epoch 8/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0065 - mae: 0.0642 - val_loss: 0.0066 - val_mae: 0.0644
# Epoch 9/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0061 - mae: 0.0622 - val_loss: 0.0063 - val_mae: 0.0634
# Epoch 10/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0058 - mae: 0.0607 - val_loss: 0.0060 - val_mae: 0.0622
# Epoch 11/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0055 - mae: 0.0593 - val_loss: 0.0058 - val_mae: 0.0607
# Epoch 12/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0053 - mae: 0.0581 - val_loss: 0.0056 - val_mae: 0.0597
# Epoch 13/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0051 - mae: 0.0571 - val_loss: 0.0055 - val_mae: 0.0589
# Epoch 14/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0050 - mae: 0.0562 - val_loss: 0.0054 - val_mae: 0.0586
# Epoch 15/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0048 - mae: 0.0556 - val_loss: 0.0053 - val_mae: 0.0581
# Epoch 16/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - mae: 0.0548 - val_loss: 0.0051 - val_mae: 0.0571
# Epoch 17/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0046 - mae: 0.0543 - val_loss: 0.0049 - val_mae: 0.0558
# Epoch 18/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0045 - mae: 0.0540 - val_loss: 0.0050 - val_mae: 0.0565
# Epoch 19/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - mae: 0.0532 - val_loss: 0.0050 - val_mae: 0.0571
# Epoch 20/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - mae: 0.0528 - val_loss: 0.0050 - val_mae: 0.0565
# Epoch 21/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0043 - mae: 0.0524 - val_loss: 0.0047 - val_mae: 0.0547
# Epoch 22/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0042 - mae: 0.0518 - val_loss: 0.0045 - val_mae: 0.0535
# Epoch 23/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - mae: 0.0515 - val_loss: 0.0045 - val_mae: 0.0534
# Epoch 24/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - mae: 0.0512 - val_loss: 0.0044 - val_mae: 0.0531
# Epoch 25/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0040 - mae: 0.0509 - val_loss: 0.0046 - val_mae: 0.0541
# Epoch 26/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0040 - mae: 0.0507 - val_loss: 0.0043 - val_mae: 0.0524
# Epoch 27/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0039 - mae: 0.0504 - val_loss: 0.0045 - val_mae: 0.0537
# Epoch 28/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0039 - mae: 0.0500 - val_loss: 0.0044 - val_mae: 0.0533
# Epoch 29/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0038 - mae: 0.0498 - val_loss: 0.0042 - val_mae: 0.0519
# Epoch 30/30
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - mae: 0.0498 - val_loss: 0.0042 - val_mae: 0.0515

# %%
series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = rnn_fully_model_dense.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X,y_pred_one],axis=1)

Y_pred = X[:, n_steps:]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
Y_pred
# Out:
# array([[[ 0.5478871 ],
#         [ 0.34595606],
#         [ 0.09934106],
#         [-0.15285155],
#         [-0.3799153 ],
#         [-0.5386981 ],
#         [-0.62749135],
#         [-0.6478457 ],
#         [-0.5869417 ],
#         [-0.48076555]]], dtype=float32)

# %%
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
model2 = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

# %%
model2.compile(loss="mse", optimizer="adam")
model2.fit(X_train, Y_train, epochs=20, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.1156 - val_loss: 0.0517
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0447 - val_loss: 0.0432
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0370 - val_loss: 0.0357
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0334 - val_loss: 0.0337
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0299 - val_loss: 0.0294
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0267 - val_loss: 0.0243
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0235 - val_loss: 0.0248
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0204 - val_loss: 0.0189
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0185 - val_loss: 0.0190
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0159 - val_loss: 0.0164
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0147 - val_loss: 0.0141
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0120 - val_loss: 0.0119
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0113 - val_loss: 0.0110
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0103 - val_loss: 0.0089
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0096 - val_loss: 0.0088
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0089 - val_loss: 0.0079
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0091 - val_loss: 0.0081
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0084 - val_loss: 0.0070

# %%
series_new = generate_time_series(1, n_steps + 10)
X_new, Y_new = series_new[:, :n_steps], series_new[:, n_steps:, 0]
Y_pred = model2.predict(X_new)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step

# %%
Y_naive = np.tile(X_valid[:, -1], 10)
print(np.mean((Y_valid - Y_naive) ** 2))
print(model2.evaluate(X_valid, Y_valid))
# Out:
# 0.50640637
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070
# 0.0069724563509225845

# %%
Y_naive
# Out:
# array([[-0.6475102 , -0.6475102 , -0.6475102 , ..., -0.6475102 ,
#         -0.6475102 , -0.6475102 ],
#        [-0.40070352, -0.40070352, -0.40070352, ..., -0.40070352,
#         -0.40070352, -0.40070352],
#        [ 0.97088933,  0.97088933,  0.97088933, ...,  0.97088933,
#          0.97088933,  0.97088933],
#        ...,
#        [-0.2361376 , -0.2361376 , -0.2361376 , ..., -0.2361376 ,
#         -0.2361376 , -0.2361376 ],
#        [ 0.13786136,  0.13786136,  0.13786136, ...,  0.13786136,
#          0.13786136,  0.13786136],
#        [ 0.88444257,  0.88444257,  0.88444257, ...,  0.88444257,
#          0.88444257,  0.88444257]], shape=(2000, 10), dtype=float32)

# %%
y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 11):
    y[:, :, step_ahead-1] = series[:, step_ahead:step_ahead+n_steps, 0]

y_train = y[:7000]
y_valid = y[7000:9000]
y_test = y[9000:]

# %%
model3 = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None,1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

# %%
def last_time_step_mse(Y_true, Y_pred):
    return tf.reduce_mean(tf.square(Y_true[:, -1] - Y_pred[:, -1]))
optimizer = keras.optimizers.Adam()
model3.compile(loss="mse", optimizer=optimizer, metrics=[last_time_step_mse])

# %%
# model3.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))

# %%
class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units, activation=None)

    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs,states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]

# %%
model4 = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True, input_shape=[None,1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])
# Out:
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\layer.py:424: UserWarning: `build()` was called on layer 'ln_simple_rnn_cell', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# C:\Users\Berkay\Desktop\ML_projects\LSTM_sentiment\Lib\site-packages\keras\src\layers\layer.py:424: UserWarning: `build()` was called on layer 'ln_simple_rnn_cell_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
