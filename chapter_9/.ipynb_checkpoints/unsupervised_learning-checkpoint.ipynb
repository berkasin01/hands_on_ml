# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %%
from sklearn.datasets import make_blobs
import numpy as np

# Clustering dataset
X_blobs, y_blobs = make_blobs(n_samples=500, centers=5, cluster_std=0.8, random_state=42)

# Moons dataset (nonlinear structure)
from sklearn.datasets import make_moons
X_moons, y_moons = make_moons(n_samples=500, noise=0.05, random_state=42)

# Anisotropic blobs (varied density)
X_aniso, y_aniso = make_blobs(n_samples=500, centers=3, random_state=42)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X_aniso, transformation)

# %%
from sklearn.cluster import KMeans

k=5 
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X_aniso)

# %%
y_pred
# Out:
# array([2, 4, 0, 1, 0, 0, 2, 0, 4, 2, 0, 1, 1, 3, 4, 0, 3, 2, 2, 1, 4, 1,
#        0, 2, 2, 0, 4, 2, 2, 1, 0, 3, 3, 3, 0, 0, 4, 4, 2, 2, 4, 1, 3, 1,
#        1, 0, 0, 0, 4, 2, 2, 3, 2, 2, 4, 3, 1, 2, 0, 2, 2, 1, 4, 2, 4, 2,
#        0, 2, 1, 0, 4, 4, 0, 2, 3, 2, 1, 0, 1, 1, 2, 3, 4, 1, 2, 2, 2, 2,
#        0, 1, 2, 4, 1, 0, 0, 2, 3, 3, 3, 2, 0, 3, 1, 2, 2, 1, 3, 2, 3, 2,
#        2, 2, 2, 2, 2, 4, 3, 2, 0, 2, 1, 1, 4, 4, 2, 0, 3, 0, 2, 2, 2, 0,
#        4, 2, 0, 2, 2, 2, 4, 3, 2, 2, 4, 4, 2, 2, 2, 3, 1, 1, 0, 2, 0, 4,
#        3, 2, 1, 2, 0, 0, 2, 2, 1, 3, 2, 3, 3, 4, 2, 2, 2, 3, 1, 2, 2, 3,
#        3, 4, 0, 4, 3, 2, 1, 1, 2, 2, 1, 4, 1, 2, 2, 2, 2, 2, 3, 0, 1, 3,
#        2, 0, 3, 1, 2, 2, 4, 2, 0, 3, 1, 2, 2, 0, 2, 3, 1, 2, 3, 2, 1, 0,
#        4, 3, 2, 3, 4, 1, 3, 2, 4, 4, 0, 4, 1, 2, 2, 2, 3, 0, 1, 0, 0, 4,
#        3, 1, 2, 2, 0, 3, 1, 0, 1, 1, 1, 1, 0, 3, 2, 1, 2, 3, 3, 3, 2, 3,
#        4, 0, 0, 3, 0, 0, 3, 3, 0, 2, 3, 3, 3, 1, 2, 2, 1, 0, 1, 3, 2, 1,
#        0, 2, 4, 0, 2, 3, 3, 1, 2, 3, 2, 4, 0, 1, 0, 2, 0, 4, 1, 0, 0, 4,
#        4, 1, 4, 2, 0, 0, 0, 2, 2, 0, 4, 1, 2, 0, 4, 2, 2, 2, 0, 2, 2, 2,
#        2, 2, 1, 2, 1, 2, 3, 3, 2, 1, 4, 0, 3, 1, 0, 3, 4, 1, 0, 0, 0, 1,
#        4, 2, 2, 4, 2, 1, 4, 3, 0, 3, 4, 0, 2, 1, 4, 4, 1, 2, 3, 2, 1, 0,
#        2, 1, 2, 0, 2, 2, 0, 2, 1, 0, 2, 2, 3, 0, 2, 0, 2, 0, 3, 1, 4, 2,
#        0, 3, 3, 1, 0, 2, 0, 3, 4, 0, 2, 2, 0, 0, 2, 3, 0, 2, 3, 0, 3, 3,
#        0, 3, 1, 3, 2, 2, 4, 1, 0, 2, 3, 3, 0, 2, 0, 4, 2, 2, 0, 0, 3, 3,
#        2, 4, 2, 1, 1, 2, 4, 2, 1, 3, 4, 2, 1, 4, 0, 0, 4, 0, 3, 0, 2, 4,
#        2, 0, 3, 1, 1, 4, 0, 1, 2, 2, 3, 3, 2, 2, 1, 2, 0, 4, 3, 1, 2, 2,
#        1, 0, 2, 2, 0, 2, 2, 1, 2, 0, 1, 2, 3, 4, 2, 4], dtype=int32)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 2.44612602, -1.90465154],
#        [-4.57597284,  7.97905661],
#        [-1.40668901, -1.29435473],
#        [-5.67459235,  9.50199233],
#        [ 1.2748495 , -0.20133192]])

# %%
X_new=np.array([[0,2],[3,2],[-3,3],[-3,2.5]])
kmeans.predict(X_new)
kmeans.transform(X_new)
# Out:
# array([[ 4.60758463,  7.52918624,  3.58211489,  9.40642798,  2.54383637],
#        [ 3.94373935,  9.65113892,  5.50197066, 11.46858498,  2.79678502],
#        [ 7.32911286,  5.22251809,  4.58040636,  7.03060086,  5.34068014],
#        [ 7.00437319,  5.70120617,  4.11530895,  7.49542132,  5.05683027]])

# %%
from sklearn.cluster import MiniBatchKMeans

minibatch_kmeans = MiniBatchKMeans(n_clusters=5)
minibatch_kmeans.fit(X_aniso)
# Out:
# MiniBatchKMeans(n_clusters=5)

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

scores = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_blobs)
    scores.append(silhouette_score(X_blobs, labels))

import matplotlib.pyplot as plt
plt.plot(k_range, scores, marker='o')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs k')
plt.show()

# %%
from matplotlib.image import imread
import os 

image= imread("images/ladybug.jpg")
image.shape
# Out:
# (1020, 1631, 3)

# %%
image
# Out:
# array([[[112, 167,   3],
#         [108, 163,   0],
#         [115, 170,   6],
#         ...,
#         [108, 157,   3],
#         [111, 160,   6],
#         [113, 160,   6]],
#
#        [[118, 173,   9],
#         [113, 168,   4],
#         [117, 172,   8],
#         ...,
#         [112, 163,   8],
#         [114, 163,   9],
#         [120, 167,  13]],
#
#        [[126, 178,  15],
#         [119, 171,   8],
#         [120, 172,   9],
#         ...,
#         [100, 151,   0],
#         [102, 151,   0],
#         [110, 157,   3]],
#
#        ...,
#
#        [[ 93, 136,   5],
#         [ 95, 138,   7],
#         [ 94, 137,   6],
#         ...,
#         [163, 178,  97],
#         [149, 164,  83],
#         [152, 167,  86]],
#
#        [[ 92, 135,   4],
#         [ 93, 136,   5],
#         [ 92, 135,   4],
#         ...,
#         [165, 180,  97],
#         [151, 166,  83],
#         [153, 168,  87]],
#
#        [[ 99, 142,  11],
#         [ 99, 142,  11],
#         [ 95, 138,   7],
#         ...,
#         [167, 182,  99],
#         [151, 166,  83],
#         [152, 167,  86]]], shape=(1020, 1631, 3), dtype=uint8)

# %%
X = image.reshape(-1,3)
X
# Out:
# array([[112, 167,   3],
#        [108, 163,   0],
#        [115, 170,   6],
#        ...,
#        [167, 182,  99],
#        [151, 166,  83],
#        [152, 167,  86]], shape=(1663620, 3), dtype=uint8)

# %%
kmeans = KMeans(n_clusters=5).fit(X)
segmented_imgs = kmeans.cluster_centers_[kmeans.labels_]
segments_imgs = segmented_imgs.reshape(image.shape)
import matplotlib.pyplot as plt

plt.imshow(segments_imgs / 255)
plt.axis('off')
plt.show()
