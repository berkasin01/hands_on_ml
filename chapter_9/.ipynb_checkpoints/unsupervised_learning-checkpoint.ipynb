# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

# %%
from sklearn.datasets import make_blobs
import numpy as np

# Clustering dataset
X_blobs, y_blobs = make_blobs(n_samples=500, centers=5, cluster_std=0.8, random_state=42)

# Moons dataset (nonlinear structure)
from sklearn.datasets import make_moons
X_moons, y_moons = make_moons(n_samples=500, noise=0.05, random_state=42)

# Anisotropic blobs (varied density)
X_aniso, y_aniso = make_blobs(n_samples=500, centers=3, random_state=42)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X_aniso, transformation)

# %%
from sklearn.cluster import KMeans

k=5 
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X_aniso)

# %%
y_pred
# Out:
# array([3, 4, 2, 1, 2, 2, 3, 2, 4, 0, 2, 1, 1, 1, 4, 2, 1, 0, 0, 1, 4, 1,
#        2, 3, 0, 2, 4, 3, 0, 1, 2, 1, 1, 1, 2, 2, 4, 4, 0, 3, 4, 1, 1, 1,
#        1, 2, 2, 2, 4, 0, 0, 1, 0, 3, 4, 1, 1, 0, 2, 0, 0, 1, 4, 3, 4, 0,
#        2, 3, 1, 2, 4, 4, 2, 3, 1, 0, 1, 2, 1, 1, 3, 1, 4, 1, 0, 0, 0, 0,
#        2, 1, 3, 4, 1, 2, 2, 3, 1, 1, 1, 3, 2, 1, 1, 0, 3, 1, 1, 3, 1, 0,
#        0, 0, 0, 3, 3, 4, 1, 0, 2, 3, 1, 1, 4, 4, 0, 2, 1, 2, 0, 3, 0, 2,
#        4, 3, 2, 0, 3, 0, 4, 1, 3, 3, 4, 4, 3, 0, 0, 1, 1, 1, 2, 0, 2, 4,
#        1, 0, 1, 3, 2, 2, 3, 0, 1, 1, 0, 1, 1, 4, 0, 0, 3, 1, 1, 0, 3, 1,
#        1, 4, 2, 4, 1, 0, 1, 1, 3, 0, 1, 4, 1, 3, 0, 0, 3, 3, 1, 2, 1, 1,
#        0, 2, 1, 1, 0, 0, 4, 3, 2, 1, 1, 0, 3, 2, 3, 1, 1, 3, 1, 3, 1, 2,
#        4, 1, 0, 1, 4, 1, 1, 3, 4, 4, 2, 4, 1, 0, 3, 0, 1, 2, 1, 2, 2, 4,
#        1, 1, 0, 3, 2, 1, 1, 2, 1, 1, 1, 1, 2, 1, 0, 1, 3, 1, 1, 1, 0, 1,
#        4, 2, 2, 1, 2, 2, 1, 1, 2, 3, 1, 1, 1, 1, 0, 0, 1, 2, 1, 1, 3, 1,
#        2, 0, 4, 2, 3, 1, 1, 1, 0, 1, 3, 4, 2, 1, 2, 3, 2, 4, 1, 2, 2, 4,
#        4, 1, 4, 0, 2, 2, 2, 0, 0, 2, 4, 1, 3, 2, 4, 0, 0, 3, 2, 0, 0, 3,
#        3, 3, 1, 0, 1, 3, 1, 1, 3, 1, 4, 2, 1, 1, 2, 1, 4, 1, 2, 2, 2, 1,
#        4, 0, 0, 4, 0, 1, 4, 1, 2, 1, 4, 2, 3, 1, 4, 4, 1, 3, 1, 3, 1, 2,
#        0, 1, 3, 2, 0, 0, 2, 3, 1, 2, 0, 0, 1, 2, 3, 2, 0, 2, 1, 1, 4, 0,
#        2, 1, 1, 1, 2, 0, 2, 1, 4, 2, 3, 3, 2, 2, 0, 1, 2, 0, 1, 2, 1, 1,
#        2, 1, 1, 1, 0, 3, 4, 1, 2, 3, 1, 1, 2, 0, 2, 4, 3, 3, 2, 3, 1, 1,
#        0, 4, 0, 1, 1, 0, 4, 0, 1, 1, 4, 3, 1, 4, 2, 2, 4, 2, 1, 2, 3, 4,
#        0, 2, 1, 1, 1, 4, 2, 1, 0, 0, 1, 1, 0, 3, 1, 3, 2, 4, 1, 1, 3, 0,
#        1, 2, 0, 3, 2, 0, 3, 1, 3, 2, 1, 3, 1, 4, 0, 4], dtype=int32)

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.90959321, -0.55503606],
#        [-5.12199331,  8.73596478],
#        [ 2.46685227, -1.89066625],
#        [-0.78799373, -2.19647961],
#        [ 1.2748495 , -0.20133192]])

# %%
X_new=np.array([[0,2],[3,2],[-3,3],[-3,2.5]])
kmeans.predict(X_new)
kmeans.transform(X_new)
# Out:
# array([[ 3.18978926,  8.46215322,  4.6068041 ,  4.26982146,  2.54383637],
#        [ 5.53464676, 10.55177696,  3.92702564,  5.65325903,  2.79678502],
#        [ 3.71850351,  6.11589304,  7.3351953 ,  5.64768732,  5.34068014],
#        [ 3.24379906,  6.58711715,  7.01173473,  5.19132859,  5.05683027]])

# %%
from sklearn.cluster import MiniBatchKMeans

minibatch_kmeans = MiniBatchKMeans(n_clusters=5)
minibatch_kmeans.fit(X_aniso)
# Out:
# MiniBatchKMeans(n_clusters=5)
