# %%
import numpy as np
import pandas as pd

# %%
import tensorflow as tf

# %%
tf.constant([[1.,2.,3.], [4.,5.,6.]])
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>
